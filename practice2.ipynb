# %%
import micrograd
from micrograd.engine import Value

a = Value(-5.0)
b = Value(3.0)
c = a + b
d = a * b + b**2
c += c + 1
c += 1 + c + (-a)
d += d * 2 + (b + a).relu()
d += 3 * d + (b - a).relu()
e = c - d
f = e**2
g = f / 2.0
g += 10.0 / f
print(f'{g.data:.4f}') # prints 24.7041, the outcome of this forward pass
# Out:
# 24.7041

# %%
print(f'{a.grad:.4f}') # prints 138.8338, i.e. the numerical value of dg/da
print(f'{b.grad:.4f}') # prints 645.5773, i.e. the numerical value of dg/db

g.backward()

print(f'{a.grad:.4f}') # prints 138.8338, i.e. the numerical value of dg/da
print(f'{b.grad:.4f}') # prints 645.5773, i.e. the numerical value of dg/db
# Out:
# 0.0000
# 0.0000
# 138.8338
# 645.5773

# %%
from micrograd.nn import Neuron, Layer, MLP

neuron1=Neuron(6,nonlin=False)

neuron1.parameters(), neuron1.__repr__()
# Out:
# ([Value(data=-0.07828640416709587, grad=0),
#   Value(data=0.6760125101829577, grad=0),
#   Value(data=-0.9124572009399634, grad=0),
#   Value(data=-0.7186249267982168, grad=0),
#   Value(data=-0.3037320475007048, grad=0),
#   Value(data=-0.38729018612194, grad=0),
#   Value(data=0, grad=0)],
#  'LinearNeuron(6)')

# %%
layer1=Layer(5,10)

# %%
layer1
# Out:
# Layer of [ReLUNeuron(5), ReLUNeuron(5), ReLUNeuron(5), ReLUNeuron(5), ReLUNeuron(5), ReLUNeuron(5), ReLUNeuron(5), ReLUNeuron(5), ReLUNeuron(5), ReLUNeuron(5)]

# %%
nin=5
nouts=[3,3]
sz = [nin]+nouts
sz
# Out:
# [5, 3, 3]

# %%
value1=Value(1.0)
layer1.neurons[0].parameters()
# Out:
# [Value(data=-0.5927145131156524, grad=0), Value(data=0, grad=0)]
